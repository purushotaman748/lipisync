# %% [markdown]
# # Collab preliminaries

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# # Get the code and models

# %%
# !git clone https://github.com/Rudrabha/Wav2Lip.git
# Out:
# Cloning into 'Wav2Lip'...
# remote: Enumerating objects: 369, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 369 (delta 4), reused 2 (delta 1), pack-reused 360
# Receiving objects: 100% (369/369), 528.93 KiB | 12.90 MiB/s, done.
# Resolving deltas: 100% (202/202), done.

# %%
# !ls
# Out:
# gdrive	sample_data  Wav2Lip

# %%
# !cp -ri "/content/gdrive/My Drive/projects/wav2lip/weights/wav2lip_gan.pth" /content/Wav2Lip/checkpoints/

# %% [markdown]
# # Get the pre-requisites

# %%
# !pip uninstall tensorflow tensorflow-gpu
# Out:
# Found existing installation: tensorflow 2.15.0
# Uninstalling tensorflow-2.15.0:
#   Would remove:
#     /usr/local/bin/estimator_ckpt_converter
#     /usr/local/bin/import_pb_to_tensorboard
#     /usr/local/bin/saved_model_cli
#     /usr/local/bin/tensorboard
#     /usr/local/bin/tf_upgrade_v2
#     /usr/local/bin/tflite_convert
#     /usr/local/bin/toco
#     /usr/local/bin/toco_from_protos
#     /usr/local/lib/python3.10/dist-packages/tensorflow-2.15.0.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/tensorflow/*
# Proceed (Y/n)? y
#   Successfully uninstalled tensorflow-2.15.0
# WARNING: Skipping tensorflow-gpu as it is not installed.

# %%
# !cd Wav2Lip && pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 9.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.5/6.5 MB 29.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
# ERROR: Could not find a version that satisfies the requirement opencv-python==4.1.0.25 (from versions: 3.4.0.14, 3.4.10.37, 3.4.11.39, 3.4.11.41, 3.4.11.43, 3.4.11.45, 3.4.13.47, 3.4.15.55, 3.4.16.57, 3.4.16.59, 3.4.17.61, 3.4.17.63, 3.4.18.65, 4.3.0.38, 4.4.0.40, 4.4.0.42, 4.4.0.44, 4.4.0.46, 4.5.1.48, 4.5.3.56, 4.5.4.58, 4.5.4.60, 4.5.5.62, 4.5.5.64, 4.6.0.66, 4.7.0.68, 4.7.0.72, 4.8.0.74, 4.8.0.76, 4.8.1.78)
# ERROR: No matching distribution found for opencv-python==4.1.0.25

# %%
# !wget "https://www.adrianbulat.com/downloads/python-fan/s3fd-619a316812.pth" -O "Wav2Lip/face_detection/detection/sfd/s3fd.pth"
# Out:
# --2023-12-16 12:52:21--  https://www.adrianbulat.com/downloads/python-fan/s3fd-619a316812.pth
# Resolving www.adrianbulat.com (www.adrianbulat.com)... 45.136.29.207
# Connecting to www.adrianbulat.com (www.adrianbulat.com)|45.136.29.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 89843225 (86M) [application/octet-stream]
# Saving to: ‘Wav2Lip/face_detection/detection/sfd/s3fd.pth’
#
# Wav2Lip/face_detect 100%[===================>]  85.68M  19.2MB/s    in 5.2s
#
# 2023-12-16 12:52:27 (16.4 MB/s) - ‘Wav2Lip/face_detection/detection/sfd/s3fd.pth’ saved [89843225/89843225]

# %% [markdown]
# # Change the Video and Audio file names

# %%
# !cp "/content/gdrive/My Drive/projects/wav2lip/input/video.mp4" "/content/gdrive/My Drive/projects/wav2lip/input/audio.wav" sample_data/
# !ls sample_data/
# Out:
# anscombe.json  california_housing_test.csv   mnist_test.csv	    README.md
# audio.wav      california_housing_train.csv  mnist_train_small.csv  video.mp4

# %% [markdown]
# # Change the Video and Audio file names here as well

# %%
# use the "files" button on the left to download the result in the Wav2Lip/results/ folder.

# %%
# !cd Wav2Lip && python inference.py --checkpoint_path checkpoints/wav2lip_gan.pth --face "../sample_data/video.mp4" --audio "../sample_data/audio.wav" --resize_factor 2
# Out:
# Using cuda for inference.
# Reading video frames...
# Number of frames available for inference: 2049
# (80, 5386)
# Length of mel chunks: 2016
#   0% 0/16 [00:00<?, ?it/s]
#   0% 0/126 [00:00<?, ?it/s]
#   1% 1/126 [00:10<21:25, 10.28s/it]
#   2% 2/126 [00:11<09:50,  4.76s/it]
#   2% 3/126 [00:12<06:06,  2.98s/it]
#   3% 4/126 [00:12<04:21,  2.15s/it]
#   4% 5/126 [00:13<03:22,  1.67s/it]
#   5% 6/126 [00:14<02:44,  1.37s/it]
#   6% 7/126 [00:15<02:18,  1.17s/it]
#   6% 8/126 [00:15<02:01,  1.03s/it]
#   7% 9/126 [00:16<01:50,  1.06it/s]
#   8% 10/126 [00:17<01:43,  1.12it/s]
#   9% 11/126 [00:18<01:38,  1.17it/s]
#  10% 12/126 [00:19<01:33,  1.22it/s]
#  10% 13/126 [00:19<01:30,  1.25it/s]
#  11% 14/126 [00:20<01:27,  1.28it/s]
#  12% 15/126 [00:21<01:26,  1.29it/s]
#  13% 16/126 [00:22<01:25,  1.29it/s]
#  13% 17/126 [00:22<01:24,  1.30it/s]
#  14% 18/126 [00:23<01:24,  1.27it/s]
#  15% 19/126 [00:24<01:27,  1.22it/s]
#  16% 20/126 [00:25<01:29,  1.19it/s]
# ...
